# %% [markdown]
# # Importar bibliotecas a serem utilizadas

# %% [markdown]
# ## Pandas - Biblioteca para manipulação de dados

# %%
import pandas as pd

# %% [markdown]
# ## BeautifulSoap e Selenium - Bibliotecas para web scraping

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

# %% [markdown]
# ## Locale e DateTime - Bibliotecas para manipulação de localização e datas

# %%
import locale
import datetime

# %% [markdown]
# ## Re - Biblioteca para manipulação de expressões regulares

# %%
import re

# %% [markdown]
# ## Bibliotecas matématicas e estatísticas

# %%
#Bibliotecas matemáticas e estatísticas
import numpy as np
from scipy.stats import spearmanr
import statistics as sts
from scipy import stats as s

# %% [markdown]
# # Inicializar selenium

# %%
options = Options() # criar uma instancia do objeto Options
options.add_argument("--headless")  # Executar o script em modo headless (sem interface)
options.add_argument("--window-size=400x800") # Definir o tamanho da janela do navegador

# %% [markdown]
# ## Inicializar chrome

# %%
driver = webdriver.Chrome(options=options)

# %% [markdown]
# # Configurar Locale

# %%
locale.setlocale(locale.LC_ALL, 'pt_PT.UTF-8') # Definir o idioma do sistema para portugues
# Out:
# 'pt_PT.UTF-8'

# %% [markdown]
# # Inicialização de variáveis

# %%
URL ='https://www.ncrangola.com/loja/particulares/pt/350-informatica#/page-{pagina}' # URL do site

# %% [markdown]
# # Funções  auxiliares

# %%
''' Função para obter página '''
def get_url(url):
    driver.get(url) #Abrir a URL
    #search_results = driver.find_element_by_xpath('/html/body/div[3]/div[1]/header/div[4]/div/div[1]/div/div[1]/a')
    #search_results.click()
    return driver.page_source  # Obter o conteúdo da página

def click_link(url):
    source = get_url(url) # Obter a página
    site_data = BeautifulSoup(source, 'html.parser') # Transformar o conteúdo da página em um objeto BeautifulSoup
    return BeautifulSoup(site_data.prettify(), 'html.parser') # Retornar o conteúdo da página


'''Funçãão para retornar um array com os produtos'''    
def get_produtos(page_source):
    produtos = [] # Criar um array para armazenar os produtos
    for produto in page_source: # Percorrer todos os produtos
        produtos.append({ 'Nome': produto.h5.get_text().strip(),
                        'Marca': produto.h6.get_text().strip(),
                        'Preco': produto.find('span', attrs={'itemprop':'price'}).text.strip(),
                        'Link': produto.find('a').get('href'),
                        'Imagem': produto.find('img').get('src'),
                        'dataConsulta': datetime.datetime.now()})
                        
    return produtos

# %% [markdown]
# # Tratamento dos dados

# %%
# Criar um dataframe para armazenar os produtos
df_produtos = pd.DataFrame(columns=['Nome','Marca','Preco','Link','Imagem','dataConsulta'])

# %%
   
# Fazer um loop para obter todas as páginas e obter os produtos
for page in range(1,8):
    url = URL.format(pagina=page) # Criar a URL com a página a ser consultada
    data = click_link(url) #Obter o conteúdo da página
    produtos = data.find_all('div', attrs={'class':'produto_geral'}) # Obter todos os produtos
    dataset= get_produtos(produtos) # Obter os produtos
    df_produtos = df_produtos.append(dataset,ignore_index=True) # Adicionar os produtos ao dataframe

# %%
df_produtos.count() # Contar o número de produtos
# Out:
# Nome            420
# Marca           420
# Preco           420
# Link            420
# Imagem          420
# dataConsulta    420
# dtype: int64

# %%
df_produtos.replace(' ', '', regex=True, inplace=True) # Remover os espaços em branco

# %%
# Substituir o símbolo de Kwanza para o símbolo de euro para se adequar ao locale
df_produtos.replace('AKZ', ' €', regex=True, inplace=True)

# %%
# Transformar o preço em float
df_produtos['Preco'] = df_produtos['Preco'].apply(lambda x: locale.atof(x.split()[0]))

# %%
# Ver o tipo de dados do DataFrame
df_produtos.dtypes
# Out:
# Nome                    object
# Marca                   object
# Preco                  float64
# Link                    object
# Imagem                  object
# dataConsulta    datetime64[ns]
# dtype: object

# %%
# Remover os produtos duplicados
df_produtos.drop_duplicates(subset=['Nome','Marca'], keep='first', inplace=True)

# %%
# Mostrar os 5 primeiros produtos
df_produtos.head()
# Out:
#                                     Nome     Marca    Preco  \
# 0                 TRANSFORMADOR65WTRAVEL    LENOVO  24176.0
# 1           ADAPTADORUSB3.0TIPO-CPARAVGA        HP  24252.0
# 2  CARTÃODEMEMÓRIASD128GBCL10170RGO!PLUS  KINGSTON  24374.0
# 3                TECLADOCOMFIO300PTPRETO        HP  24403.0
# 4           RATOSEMFIOWIRELESSZ4000PRETO        HP  24692.0
#
#                                                 Link  \
# 0  https://www.ncrangola.com/loja/particulares/pt...
# 1  https://www.ncrangola.com/loja/particulares/pt...
# 2  https://www.ncrangola.com/loja/particulares/pt...
# 3  https://www.ncrangola.com/loja/particulares/pt...
# 4  https://www.ncrangola.com/loja/particulares/pt...
#
#                                               Imagem  \
# 0  https://www.ncrangola.com/loja/particulares/15...
# 1  https://www.ncrangola.com/loja/particulares/16...
# 2  https://www.ncrangola.com/loja/particulares/28...
# 3  https://www.ncrangola.com/loja/particulares/23...
# 4  https://www.ncrangola.com/loja/particulares/20...
#
#                 dataConsulta
# 0 2021-11-19 14:24:35.045070
# 1 2021-11-19 14:24:35.045257
# 2 2021-11-19 14:24:35.045516
# 3 2021-11-19 14:24:35.045709
# 4 2021-11-19 14:24:35.045891

# %%
# Mostrar a contagem de itens em cada coluna
df_produtos.count()
# Out:
# Nome            119
# Marca           119
# Preco           119
# Link            119
# Imagem          119
# dataConsulta    119
# dtype: int64

# %% [markdown]
# # Formatação de dados pandas

# %%
# Formatar o dataframe para que os valores sejam apresentados como float
formato = { 'Preco': '{0:,.2f} Kz'}
df_produtos.head().style.format(formato)
# Out:
# <style type="text/css">
# </style>
# <table id="T_18ad8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Nome</th>
#       <th class="col_heading level0 col1" >Marca</th>
#       <th class="col_heading level0 col2" >Preco</th>
#       <th class="col_heading level0 col3" >Link</th>
#       <th class="col_heading level0 col4" >Imagem</th>
#       <th class="col_heading level0 col5" >dataConsulta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18ad8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18ad8_row0_col0" class="data row0 col0" >TRANSFORMADOR65WTRAVEL</td>
#       <td id="T_18ad8_row0_col1" class="data row0 col1" >LENOVO</td>
#       <td id="T_18ad8_row0_col2" class="data row0 col2" >24,176.00 Kz</td>
#       <td id="T_18ad8_row0_col3" class="data row0 col3" >https://www.ncrangola.com/loja/particulares/pt/transformadores/12030-transf-lenovo-65w-travel-ac-adapt.html</td>
#       <td id="T_18ad8_row0_col4" class="data row0 col4" >https://www.ncrangola.com/loja/particulares/15146-home_default/transf-lenovo-65w-travel-ac-adapt.jpg</td>
#       <td id="T_18ad8_row0_col5" class="data row0 col5" >2021-11-19 14:24:35.045070</td>
#     </tr>
#     <tr>
#       <th id="T_18ad8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18ad8_row1_col0" class="data row1 col0" >ADAPTADORUSB3.0TIPO-CPARAVGA</td>
#       <td id="T_18ad8_row1_col1" class="data row1 col1" >HP</td>
#       <td id="T_18ad8_row1_col2" class="data row1 col2" >24,252.00 Kz</td>
#       <td id="T_18ad8_row1_col3" class="data row1 col3" >https://www.ncrangola.com/loja/particulares/pt/adaptadores/13915-adapt-usb-c-to-vga-hp.html</td>
#       <td id="T_18ad8_row1_col4" class="data row1 col4" >https://www.ncrangola.com/loja/particulares/16449-home_default/adapt-usb-c-to-vga-hp.jpg</td>
#       <td id="T_18ad8_row1_col5" class="data row1 col5" >2021-11-19 14:24:35.045257</td>
#     </tr>
#     <tr>
#       <th id="T_18ad8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_18ad8_row2_col0" class="data row2 col0" >CARTÃODEMEMÓRIASD128GBCL10170RGO!PLUS</td>
#       <td id="T_18ad8_row2_col1" class="data row2 col1" >KINGSTON</td>
#       <td id="T_18ad8_row2_col2" class="data row2 col2" >24,374.00 Kz</td>
#       <td id="T_18ad8_row2_col3" class="data row2 col3" >https://www.ncrangola.com/loja/particulares/pt/cartoes-de-memoria/18126-mod-sd-card-128gb-cl10-kingston-170r-go-plus.html</td>
#       <td id="T_18ad8_row2_col4" class="data row2 col4" >https://www.ncrangola.com/loja/particulares/28602-home_default/mod-sd-card-128gb-cl10-kingston-170r-go-plus.jpg</td>
#       <td id="T_18ad8_row2_col5" class="data row2 col5" >2021-11-19 14:24:35.045516</td>
#     </tr>
#     <tr>
#       <th id="T_18ad8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_18ad8_row3_col0" class="data row3 col0" >TECLADOCOMFIO300PTPRETO</td>
#       <td id="T_18ad8_row3_col1" class="data row3 col1" >HP</td>
#       <td id="T_18ad8_row3_col2" class="data row3 col2" >24,403.00 Kz</td>
#       <td id="T_18ad8_row3_col3" class="data row3 col3" >https://www.ncrangola.com/loja/particulares/pt/rato-e-teclado/15358-teclado-hp-usb-300.html</td>
#       <td id="T_18ad8_row3_col4" class="data row3 col4" >https://www.ncrangola.com/loja/particulares/23320-home_default/teclado-hp-usb-300.jpg</td>
#       <td id="T_18ad8_row3_col5" class="data row3 col5" >2021-11-19 14:24:35.045709</td>
#     </tr>
#     <tr>
#       <th id="T_18ad8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_18ad8_row4_col0" class="data row4 col0" >RATOSEMFIOWIRELESSZ4000PRETO</td>
#       <td id="T_18ad8_row4_col1" class="data row4 col1" >HP</td>
#       <td id="T_18ad8_row4_col2" class="data row4 col2" >24,692.00 Kz</td>
#       <td id="T_18ad8_row4_col3" class="data row4 col3" >https://www.ncrangola.com/loja/particulares/pt/rato-e-teclado/1537-rato-hp-wifi-z4000-preto.html</td>
#       <td id="T_18ad8_row4_col4" class="data row4 col4" >https://www.ncrangola.com/loja/particulares/20247-home_default/rato-hp-wifi-z4000-preto.jpg</td>
#       <td id="T_18ad8_row4_col5" class="data row4 col5" >2021-11-19 14:24:35.045891</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Análise de dados

# %% [markdown]
# ### Análise de dados - Total de produtos

# %%
# Mostrar o total de produtos
print('Total de produtos:',len(df_produtos),sep=':')
# Out:
# Total de produtos::119

# %% [markdown]
# ## Agrupamento de dados

# %% [markdown]
# ### Agrupamento de dados usando funções matématicas básicas.

# %% [markdown]
# #### Agrupamento de dados - contagem,média,médiana,desvio padrão, max e minímo.

# %%
agg_funcao_math = {'Preco': ['min', 'max', 'mean', 'median', 'std']} # Definir as funções matemáticas a serem aplicadas

df_produtos.groupby('Marca').agg(agg_funcao_math).round(2)
# Out:
#                    Preco
#                      min       max      mean    median       std
# Marca
# AVERY            9827.00   9827.00   9827.00   9827.00       NaN
# CASELOGIC        7137.00  24838.00  15987.50  15987.50  12516.50
# CELLY            7169.00   9804.00   8372.50   8144.50   1341.82
# DLINK            8796.24  27643.86  19833.25  26387.58   9570.77
# FELLOWES         8707.32   9462.00   9084.66   9084.66    533.64
# GENIUS           7249.00   8705.00   8137.87   8705.00    719.67
# HP               8167.00  32669.00  25108.73  26300.00   7327.00
# INTELLINET       8268.00  25657.00  13234.50   9506.50   8302.24
# KASPERSKY        9952.00   9952.00   9952.00   9952.00       NaN
# KINGSLONG        8384.00   8934.00   8590.33   8453.00    271.52
# KINGSTON         9275.00  35014.00  27524.98  30736.44   9756.29
# KSTATIONERY     25345.00  25345.00  25345.00  25345.00       NaN
# LDNIO            7764.00   7764.00   7764.00   7764.00       NaN
# LENOVO          24176.00  24176.00  24176.00  24176.00       NaN
# MANHATTAN        7307.00  34633.00  14360.85   9330.00   9657.35
# MARSHMALLOW     25616.00  25616.00  25616.00  25616.00       NaN
# MAXELL           7143.00  31806.00  12586.30   8692.00   9259.64
# MISSLEMONADE    25081.00  26701.00  26006.71  26701.00    865.93
# NCR             26701.00  26701.00  26701.00  26701.00       NaN
# NGS              8162.00  30081.00  22700.33  29858.00  12591.06
# SAMSUNG         31595.00  31595.00  31595.00  31595.00       NaN
# TARGUS          24913.00  32307.00  27067.80  25839.00   2979.31
# THULE           31285.00  31285.00  31285.00  31285.00       NaN
# TOSHIBA         26007.00  26007.00  26007.00  26007.00       NaN
# TRANSCEND        8011.00  30725.00  14230.50   9365.00   9811.07
# UNKEEPER        24744.00  24744.00  24744.00  24744.00      0.00
# WESTERNDIGITAL  32289.36  32289.36  32289.36  32289.36       NaN
# WINTECH         24940.00  24940.00  24940.00  24940.00       NaN
# XIAOMI          28022.00  28022.00  28022.00  28022.00       NaN

# %% [markdown]
# #### Agrupamento de dados - Resumo estátistico

# %%
agg_funcao_estatistica = {'Preco': ['describe']} # Definir as funções estatísticas a serem aplicadas
df_produtos.groupby('Marca').agg(agg_funcao_estatistica).round(2)
# Out:
#                   Preco                                                    \
#                describe
#                   count      mean       std       min       25%       50%
# Marca
# AVERY               1.0   9827.00       NaN   9827.00   9827.00   9827.00
# CASELOGIC           2.0  15987.50  12516.50   7137.00  11562.25  15987.50
# CELLY               6.0   8372.50   1341.82   7169.00   7169.00   8144.50
# DLINK               5.0  19833.25   9570.77   8796.24   9951.00  26387.58
# FELLOWES            2.0   9084.66    533.64   8707.32   8895.99   9084.66
# GENIUS              7.0   8137.87    719.67   7249.00   7448.06   8705.00
# HP                 15.0  25108.73   7327.00   8167.00  24547.50  26300.00
# INTELLINET          4.0  13234.50   8302.24   8268.00   9180.75   9506.50
# KASPERSKY           1.0   9952.00       NaN   9952.00   9952.00   9952.00
# KINGSLONG           6.0   8590.33    271.52   8384.00   8384.00   8453.00
# KINGSTON            6.0  27524.98   9756.29   9275.00  25899.00  30736.44
# KSTATIONERY         1.0  25345.00       NaN  25345.00  25345.00  25345.00
# LDNIO               1.0   7764.00       NaN   7764.00   7764.00   7764.00
# LENOVO              1.0  24176.00       NaN  24176.00  24176.00  24176.00
# MANHATTAN          17.0  14360.85   9657.35   7307.00   7634.00   9330.00
# MARSHMALLOW         1.0  25616.00       NaN  25616.00  25616.00  25616.00
# MAXELL             10.0  12586.30   9259.64   7143.00   8011.25   8692.00
# MISSLEMONADE        7.0  26006.71    865.93  25081.00  25081.00  26701.00
# NCR                 1.0  26701.00       NaN  26701.00  26701.00  26701.00
# NGS                 3.0  22700.33  12591.06   8162.00  19010.00  29858.00
# SAMSUNG             1.0  31595.00       NaN  31595.00  31595.00  31595.00
# TARGUS              5.0  27067.80   2979.31  24913.00  25839.00  25839.00
# THULE               1.0  31285.00       NaN  31285.00  31285.00  31285.00
# TOSHIBA             1.0  26007.00       NaN  26007.00  26007.00  26007.00
# TRANSCEND           8.0  14230.50   9811.07   8011.00   8740.25   9365.00
# UNKEEPER            3.0  24744.00      0.00  24744.00  24744.00  24744.00
# WESTERNDIGITAL      1.0  32289.36       NaN  32289.36  32289.36  32289.36
# WINTECH             1.0  24940.00       NaN  24940.00  24940.00  24940.00
# XIAOMI              1.0  28022.00       NaN  28022.00  28022.00  28022.00
#
#
#
#                      75%       max
# Marca
# AVERY            9827.00   9827.00
# CASELOGIC       20412.75  24838.00
# CELLY            9633.00   9804.00
# DLINK           26387.58  27643.86
# FELLOWES         9273.33   9462.00
# GENIUS           8705.00   8705.00
# HP              29602.00  32669.00
# INTELLINET      13560.25  25657.00
# KASPERSKY        9952.00   9952.00
# KINGSLONG        8831.00   8934.00
# KINGSTON        34010.22  35014.00
# KSTATIONERY     25345.00  25345.00
# LDNIO            7764.00   7764.00
# LENOVO          24176.00  24176.00
# MANHATTAN       24753.00  34633.00
# MARSHMALLOW     25616.00  25616.00
# MAXELL           8995.75  31806.00
# MISSLEMONADE    26701.00  26701.00
# NCR             26701.00  26701.00
# NGS             29969.50  30081.00
# SAMSUNG         31595.00  31595.00
# TARGUS          26441.00  32307.00
# THULE           31285.00  31285.00
# TOSHIBA         26007.00  26007.00
# TRANSCEND       14695.25  30725.00
# UNKEEPER        24744.00  24744.00
# WESTERNDIGITAL  32289.36  32289.36
# WINTECH         24940.00  24940.00
# XIAOMI          28022.00  28022.00

# %%
df_produtos.groupby('Marca')['Preco'].agg(['min','max','mean','median','std']).style.format('{0:,.2f} Kz')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d0211_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >min</th>
#       <th class="col_heading level0 col1" >max</th>
#       <th class="col_heading level0 col2" >mean</th>
#       <th class="col_heading level0 col3" >median</th>
#       <th class="col_heading level0 col4" >std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Marca</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0211_level0_row0" class="row_heading level0 row0" >AVERY</th>
#       <td id="T_d0211_row0_col0" class="data row0 col0" >9,827.00 Kz</td>
#       <td id="T_d0211_row0_col1" class="data row0 col1" >9,827.00 Kz</td>
#       <td id="T_d0211_row0_col2" class="data row0 col2" >9,827.00 Kz</td>
#       <td id="T_d0211_row0_col3" class="data row0 col3" >9,827.00 Kz</td>
#       <td id="T_d0211_row0_col4" class="data row0 col4" >0.00 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row1" class="row_heading level0 row1" >CASELOGIC</th>
#       <td id="T_d0211_row1_col0" class="data row1 col0" >7,137.00 Kz</td>
#       <td id="T_d0211_row1_col1" class="data row1 col1" >7,137.00 Kz</td>
#       <td id="T_d0211_row1_col2" class="data row1 col2" >7,137.00 Kz</td>
#       <td id="T_d0211_row1_col3" class="data row1 col3" >7,137.00 Kz</td>
#       <td id="T_d0211_row1_col4" class="data row1 col4" >0.00 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row2" class="row_heading level0 row2" >CELLY</th>
#       <td id="T_d0211_row2_col0" class="data row2 col0" >7,169.00 Kz</td>
#       <td id="T_d0211_row2_col1" class="data row2 col1" >9,804.00 Kz</td>
#       <td id="T_d0211_row2_col2" class="data row2 col2" >8,372.50 Kz</td>
#       <td id="T_d0211_row2_col3" class="data row2 col3" >8,144.50 Kz</td>
#       <td id="T_d0211_row2_col4" class="data row2 col4" >1,245.85 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row3" class="row_heading level0 row3" >DLINK</th>
#       <td id="T_d0211_row3_col0" class="data row3 col0" >8,796.24 Kz</td>
#       <td id="T_d0211_row3_col1" class="data row3 col1" >9,951.00 Kz</td>
#       <td id="T_d0211_row3_col2" class="data row3 col2" >9,373.62 Kz</td>
#       <td id="T_d0211_row3_col3" class="data row3 col3" >9,373.62 Kz</td>
#       <td id="T_d0211_row3_col4" class="data row3 col4" >608.61 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row4" class="row_heading level0 row4" >FELLOWES</th>
#       <td id="T_d0211_row4_col0" class="data row4 col0" >8,707.32 Kz</td>
#       <td id="T_d0211_row4_col1" class="data row4 col1" >9,462.00 Kz</td>
#       <td id="T_d0211_row4_col2" class="data row4 col2" >9,084.66 Kz</td>
#       <td id="T_d0211_row4_col3" class="data row4 col3" >9,084.66 Kz</td>
#       <td id="T_d0211_row4_col4" class="data row4 col4" >397.75 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row5" class="row_heading level0 row5" >GENIUS</th>
#       <td id="T_d0211_row5_col0" class="data row5 col0" >7,249.00 Kz</td>
#       <td id="T_d0211_row5_col1" class="data row5 col1" >8,705.00 Kz</td>
#       <td id="T_d0211_row5_col2" class="data row5 col2" >8,137.87 Kz</td>
#       <td id="T_d0211_row5_col3" class="data row5 col3" >8,705.00 Kz</td>
#       <td id="T_d0211_row5_col4" class="data row5 col4" >676.01 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row6" class="row_heading level0 row6" >HP</th>
#       <td id="T_d0211_row6_col0" class="data row6 col0" >8,167.00 Kz</td>
#       <td id="T_d0211_row6_col1" class="data row6 col1" >8,306.00 Kz</td>
#       <td id="T_d0211_row6_col2" class="data row6 col2" >8,236.50 Kz</td>
#       <td id="T_d0211_row6_col3" class="data row6 col3" >8,236.50 Kz</td>
#       <td id="T_d0211_row6_col4" class="data row6 col4" >73.26 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row7" class="row_heading level0 row7" >INTELLINET</th>
#       <td id="T_d0211_row7_col0" class="data row7 col0" >8,268.00 Kz</td>
#       <td id="T_d0211_row7_col1" class="data row7 col1" >9,528.00 Kz</td>
#       <td id="T_d0211_row7_col2" class="data row7 col2" >9,093.67 Kz</td>
#       <td id="T_d0211_row7_col3" class="data row7 col3" >9,485.00 Kz</td>
#       <td id="T_d0211_row7_col4" class="data row7 col4" >604.60 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row8" class="row_heading level0 row8" >KINGSLONG</th>
#       <td id="T_d0211_row8_col0" class="data row8 col0" >8,384.00 Kz</td>
#       <td id="T_d0211_row8_col1" class="data row8 col1" >8,934.00 Kz</td>
#       <td id="T_d0211_row8_col2" class="data row8 col2" >8,590.33 Kz</td>
#       <td id="T_d0211_row8_col3" class="data row8 col3" >8,453.00 Kz</td>
#       <td id="T_d0211_row8_col4" class="data row8 col4" >252.10 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row9" class="row_heading level0 row9" >KINGSTON</th>
#       <td id="T_d0211_row9_col0" class="data row9 col0" >9,275.00 Kz</td>
#       <td id="T_d0211_row9_col1" class="data row9 col1" >9,275.00 Kz</td>
#       <td id="T_d0211_row9_col2" class="data row9 col2" >9,275.00 Kz</td>
#       <td id="T_d0211_row9_col3" class="data row9 col3" >9,275.00 Kz</td>
#       <td id="T_d0211_row9_col4" class="data row9 col4" >0.00 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row10" class="row_heading level0 row10" >LDNIO</th>
#       <td id="T_d0211_row10_col0" class="data row10 col0" >7,764.00 Kz</td>
#       <td id="T_d0211_row10_col1" class="data row10 col1" >7,764.00 Kz</td>
#       <td id="T_d0211_row10_col2" class="data row10 col2" >7,764.00 Kz</td>
#       <td id="T_d0211_row10_col3" class="data row10 col3" >7,764.00 Kz</td>
#       <td id="T_d0211_row10_col4" class="data row10 col4" >0.00 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row11" class="row_heading level0 row11" >MANHATTAN</th>
#       <td id="T_d0211_row11_col0" class="data row11 col0" >7,307.00 Kz</td>
#       <td id="T_d0211_row11_col1" class="data row11 col1" >9,895.00 Kz</td>
#       <td id="T_d0211_row11_col2" class="data row11 col2" >8,486.58 Kz</td>
#       <td id="T_d0211_row11_col3" class="data row11 col3" >8,354.50 Kz</td>
#       <td id="T_d0211_row11_col4" class="data row11 col4" >1,001.34 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row12" class="row_heading level0 row12" >MAXELL</th>
#       <td id="T_d0211_row12_col0" class="data row12 col0" >7,143.00 Kz</td>
#       <td id="T_d0211_row12_col1" class="data row12 col1" >9,079.00 Kz</td>
#       <td id="T_d0211_row12_col2" class="data row12 col2" >8,223.12 Kz</td>
#       <td id="T_d0211_row12_col3" class="data row12 col3" >8,544.00 Kz</td>
#       <td id="T_d0211_row12_col4" class="data row12 col4" >709.97 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row13" class="row_heading level0 row13" >NCR</th>
#       <td id="T_d0211_row13_col0" class="data row13 col0" >7,115.00 Kz</td>
#       <td id="T_d0211_row13_col1" class="data row13 col1" >7,115.00 Kz</td>
#       <td id="T_d0211_row13_col2" class="data row13 col2" >7,115.00 Kz</td>
#       <td id="T_d0211_row13_col3" class="data row13 col3" >7,115.00 Kz</td>
#       <td id="T_d0211_row13_col4" class="data row13 col4" >0.00 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row14" class="row_heading level0 row14" >NGS</th>
#       <td id="T_d0211_row14_col0" class="data row14 col0" >8,162.00 Kz</td>
#       <td id="T_d0211_row14_col1" class="data row14 col1" >8,162.00 Kz</td>
#       <td id="T_d0211_row14_col2" class="data row14 col2" >8,162.00 Kz</td>
#       <td id="T_d0211_row14_col3" class="data row14 col3" >8,162.00 Kz</td>
#       <td id="T_d0211_row14_col4" class="data row14 col4" >0.00 Kz</td>
#     </tr>
#     <tr>
#       <th id="T_d0211_level0_row15" class="row_heading level0 row15" >TRANSCEND</th>
#       <td id="T_d0211_row15_col0" class="data row15 col0" >8,011.00 Kz</td>
#       <td id="T_d0211_row15_col1" class="data row15 col1" >9,777.00 Kz</td>

# %% [markdown]
# #### Contagem de dados

# %%
agg_funcao_contagem = {'Preco' : ['count','nunique','size']} # Definir as funções de contagem a serem aplicadas
df_produtos.groupby('Marca').agg(agg_funcao_contagem).round(2)
# Out:
#                Preco
#                count nunique size
# Marca
# AVERY              1       1    1
# CASELOGIC          2       2    2
# CELLY              6       3    6
# DLINK              5       4    5
# FELLOWES           2       2    2
# GENIUS             7       3    7
# HP                15      15   15
# INTELLINET         4       4    4
# KASPERSKY          1       1    1
# KINGSLONG          6       3    6
# KINGSTON           6       5    6
# KSTATIONERY        1       1    1
# LDNIO              1       1    1
# LENOVO             1       1    1
# MANHATTAN         17      15   17
# MARSHMALLOW        1       1    1
# MAXELL            10      10   10
# MISSLEMONADE       7       2    7
# NCR                1       1    1
# NGS                3       3    3
# SAMSUNG            1       1    1
# TARGUS             5       4    5
# THULE              1       1    1
# TOSHIBA            1       1    1
# TRANSCEND          8       8    8
# UNKEEPER           3       1    3
# WESTERNDIGITAL     1       1    1
# WINTECH            1       1    1
# XIAOMI             1       1    1

# %% [markdown]
# #### Agrupamento de dados - Maior e Menor Preço

# %%
#agg_funcao_maior_menor = {'Preco' : ['first','last']} # Definir as funções de maior e menor a serem aplicadas
agg_funcao_maior_menor = {'Preco' : ['min','max']} # Definir as funções de maior e menor a serem aplicadas
#agg_funcao_maior_menor = {'Preco' : ['idxmin','idxmax']} #inidice do valor maximo e minimo
df_produtos.groupby('Marca').agg(agg_funcao_maior_menor).round(2)
# Out:
#                    Preco
#                      min       max
# Marca
# AVERY            9827.00   9827.00
# CASELOGIC        7137.00  24838.00
# CELLY            7169.00   9804.00
# DLINK            8796.24  27643.86
# FELLOWES         8707.32   9462.00
# GENIUS           7249.00   8705.00
# HP               8167.00  32669.00
# INTELLINET       8268.00  25657.00
# KASPERSKY        9952.00   9952.00
# KINGSLONG        8384.00   8934.00
# KINGSTON         9275.00  35014.00
# KSTATIONERY     25345.00  25345.00
# LDNIO            7764.00   7764.00
# LENOVO          24176.00  24176.00
# MANHATTAN        7307.00  34633.00
# MARSHMALLOW     25616.00  25616.00
# MAXELL           7143.00  31806.00
# MISSLEMONADE    25081.00  26701.00
# NCR             26701.00  26701.00
# NGS              8162.00  30081.00
# SAMSUNG         31595.00  31595.00
# TARGUS          24913.00  32307.00
# THULE           31285.00  31285.00
# TOSHIBA         26007.00  26007.00
# TRANSCEND        8011.00  30725.00
# UNKEEPER        24744.00  24744.00
# WESTERNDIGITAL  32289.36  32289.36
# WINTECH         24940.00  24940.00
# XIAOMI          28022.00  28022.00

# %% [markdown]
# #### Agrupamento de dados - Stats

# %% [markdown]
# # Exportação dos dados para excel

# %%
df_produtos.to_excel('NCR_produtos_3.xlsx',index=False) # Exportar o dataframe para um arquivo Excel
